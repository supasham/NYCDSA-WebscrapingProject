# %% [markdown]
# # Clean, stitch and analyse red wine data scraped from LCBO and Vivino

# %% [markdown]
# This notebook uses data scraped from LCBO and Vivino websites to help a Canadian  decide which red wine offers the most value for a prescribed price point.
#
# The Liquor Control Board of Ontario ("LCBO") is a Crown corporation that retails and distributes alcoholic beverages throughout the Canadian province of Ontario. It regulates the importation and pricing of alcoholic beverages within Ontario.
#
# Vivino is an online wine marketplace and app with a database of over 10 million wines and over 35 million users. It is one of the leading websites for reviews and ratings for wine.
#
# Combining the price information from the LCBO with the rating information would enable an Ontarian red-wine consumer to make choices around their purchases of red wine that offer value. Even if the value is perceived value, it makes a consumer feel better about their purchase. Increased consumer confidence is likely to lead to increased consumption from a general economic standpoint.

# %% [markdown]
# ## Load required packages and data from scraped .csv files

# %%
# Load packages and modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
# Load .csv files as dataframes

# dataframe dfl for LCBO data
dfl = pd.read_csv('lcbo_redwine.csv')

# datafram dfv for vivno data
dfv = pd.read_csv('vivino_redwine.csv')

# %%
# Check the LCBO df
dfl.head()
# Out:
#                                             name            region  size-mL  \
# 0                 Château Lafite-Rothschild 1986  Bordeaux, France     1500
# 1                                        Masseto    Tuscany, Italy     6000
# 2                 Château Mouton Rothschild 2005  Bordeaux, France     3000
# 3                           Château Margaux 1983  Bordeaux, France     1500
# 4  Domaine Leroy Clos de la Roche Grand Cru 2013  Burgundy, France      750
#
#   container   price critic  critic_score
# 0    bottle  9990.0     RP          98.0
# 1    bottle  9950.0   none           0.0
# 2    bottle  6690.0     RP          98.0
# 3    bottle  6400.0     WS          98.0
# 4    bottle  5970.0     RP          93.0

# %%
# Check the vivino df
dfv.head()
# Out:
#                                                 name       region  \
# 0  Hundred Acre Kayli Morgan Vineyard Cabernet Sa...  Napa Valley
# 1  Hundred Acre Kayli Morgan Vineyard Cabernet Sa...  Napa Valley
# 2                        Frank Family Patriarch 2012   Rutherford
# 3                     Alves de Sousa Abandonado 2017        Douro
# 4  Hundred Acre Few and Far Between Cabernet Sauv...  Napa Valley
#
#          country  num_reviews  rating   acidity fizziness  intensity  \
# 0  United States          154     4.9  3.342901      None   4.795382
# 1  United States           93     4.9  3.342901      None   4.795382
# 2  United States           83     4.9  3.324213      None   4.867668
# 3       Portugal           82     4.9  3.136328      None   4.600985
# 4  United States           62     4.9  3.375779      None   4.697957
#
#    sweetness    tannin            varietal              body
# 0   1.734349  3.375026  Cabernet Sauvignon  Very full-bodied
# 1   1.734349  3.375026  Cabernet Sauvignon  Very full-bodied
# 2   1.365278  3.291373  Cabernet Sauvignon  Very full-bodied
# 3   1.788706  3.624941           Douro Red  Very full-bodied
# 4   1.826885  3.368793  Cabernet Sauvignon  Very full-bodied

# %% [markdown]
# ## Analyse and clean data and stitch Vivino data to LCBO data

# %% [markdown]
# ### First analyse LCBO data

# %%
# Summary stats of continuous variables
dfl.describe()
# Out:
#            size-mL        price  critic_score
# count  6089.000000  6089.000000   6075.000000
# mean    817.182789   109.354533     38.682469
# std     404.069473   364.336190     46.024468
# min       2.000000     2.350000      0.000000
# 25%     750.000000    18.950000      0.000000
# 50%     750.000000    30.750000      0.000000
# 75%     750.000000    73.000000     93.000000
# max    6000.000000  9990.000000    100.000000

# %%
# Explore minimum size of 2ml, looks to be incorrect
dfl[dfl['size-mL'] == 2]
# Out:
#                                                name          region  size-mL  \
# 1854  Mazzei Ser Lapo Riserva Chianti Classico 2017  Tuscany, Italy        2
#
#      container  price critic  critic_score
# 1854      gift  58.95     JS          95.0

# %% [markdown]
# <img src="https://www.lcbo.com/content/dam/lcbo/products/016818.jpg/jcr:content/renditions/cq5dam.web.319.319.jpeg" style="height: 300px;">
# *Source: LCBO website*
#
# It turns out that this is actually a giftbox consisting of 2 bottles of 750mL of wine. Hence Replace data point with 1500mL

# %%
dfl.loc[dfl['size-mL']==2,'size-mL'] = 1500

# %%
dfl.describe()
# Out:
#            size-mL        price  critic_score
# count  6089.000000  6089.000000   6075.000000
# mean    817.428806   109.354533     38.682469
# std     404.029094   364.336190     46.024468
# min       6.000000     2.350000      0.000000
# 25%     750.000000    18.950000      0.000000
# 50%     750.000000    30.750000      0.000000
# 75%     750.000000    73.000000     93.000000
# max    6000.000000  9990.000000    100.000000

# %%
# Looks like there are more issues with size. Explore sizes less than 250ml
dfl[dfl['size-mL'] <250]
# Out:
#                                                    name              region  \
# 1251  Tedeschi Capitel Monte Olmi Amarone della Valp...       Veneto, Italy
# 1539           Osborne Solaz Tempranillo Cabernet Offer        Rueda, Spain
# 1941   Buscado Vivo o Muerto La Verdad Gualtallary 2016  Mendoza, Argentina
# 2644                             Bell'Aja Bolgheri 2017      Tuscany, Italy
# 6080                    Copa di Vino Cabernet Sauvignon         Oregon, USA
# 6081                                Copa di Vino Merlot         Oregon, USA
# 6086            Peller Family Vineyards Cabernet Merlot     Ontario, Canada
# 6088                                       Ciao Sangria       Veneto, Italy
#
#       size-mL container  price critic  critic_score
# 1251        6    bottle  89.00   none           0.0
# 1539        6    bottle  72.00   none           0.0
# 1941        6    bottle  55.00    TAT          96.0
# 2644        6    bottle  37.95     JS          91.0
# 6080      200    bottle   4.90   none           0.0
# 6081      200    bottle   4.90   none           0.0
# 6086      200    bottle   3.75   none           0.0
# 6088      200       can   2.35   none           0.0

# %% [markdown]
# Luckily there are only 4 data points to fix (200mL bottles are correct but the 4 with 6 is actually 6 bottles of certain size)
#
# 1) Tedeschi is 6*125mL
# 2) Osborne is 6*750mL
# 3) Buscado is 6*125mL
# 4) Bellaja is 6*125mL

# %%
# Update correct size in mL for gift packs or offers
dfl.loc[1251, 'size-mL'] = 6*125
dfl.loc[1539, 'size-mL'] = 6*750
dfl.loc[1941, 'size-mL'] = 6*125
dfl.loc[2644, 'size-mL'] = 6*125

# %%
# Create new variable which normalises price per mL called unit_price
dfl['unit_price'] = dfl['price'] / dfl['size-mL']
dfl.head()
# Out:
#                                             name            region  size-mL  \
# 0                 Château Lafite-Rothschild 1986  Bordeaux, France     1500
# 1                                        Masseto    Tuscany, Italy     6000
# 2                 Château Mouton Rothschild 2005  Bordeaux, France     3000
# 3                           Château Margaux 1983  Bordeaux, France     1500
# 4  Domaine Leroy Clos de la Roche Grand Cru 2013  Burgundy, France      750
#
#   container   price critic  critic_score  unit_price
# 0    bottle  9990.0     RP          98.0    6.660000
# 1    bottle  9950.0   none           0.0    1.658333
# 2    bottle  6690.0     RP          98.0    2.230000
# 3    bottle  6400.0     WS          98.0    4.266667
# 4    bottle  5970.0     RP          93.0    7.960000

# %%
# Everything looks good for continuous variables. When professional critic scores are not available, they have been set to zero
dfl.describe()
# Out:
#            size-mL        price  critic_score   unit_price
# count  6089.000000  6089.000000   6075.000000  6089.000000
# mean    818.533421   109.354533     38.682469     0.117551
# std     406.245591   364.336190     46.024468     0.298816
# min     200.000000     2.350000      0.000000     0.007733
# 25%     750.000000    18.950000      0.000000     0.025267
# 50%     750.000000    30.750000      0.000000     0.040467
# 75%     750.000000    73.000000     93.000000     0.096467
# max    6000.000000  9990.000000    100.000000     7.960000

# %%
# Value count of categorical variables
categorical = ['name', 'region', 'container', 'critic']

for feature in categorical:
    print(dfl[feature].value_counts())
    print('')
# Out:
# Château Palmer                                                         4
# Peller Family Vineyards Cabernet Merlot                                4
# Castelgiocondo Ripe al Convento Riserva Brunello di Montalcino 2013    4
# Bodacious Smooth Red                                                   4
# Antinori Guado al Tasso 2011                                           3
#                                                                       ..
# Kilikanoon Killerman's Run Cabernet Sauvignon 2017                     1
# Château Dassault 2016                                                  1
# Lakeview Cabernet Sauvignon 2015                                       1
# Château Dassault 2015                                                  1
# Château de Lamarque 2017                                               1
# Name: name, Length: 5890, dtype: int64
#
# California, USA         624
# Tuscany, Italy          466
# Bordeaux, France        449
# Ontario, Canada         333
# Burgundy, France        293
#                        ...
# Lontué Valley, Chile      1
# Achaia, Greece            1
# Nova Scotia, Canada       1
# Mallorca, Spain           1
# Valdepenas, Spain         1
# Name: region, Length: 187, dtype: int64
#
# bottle     6043
# bagnbox      26
# can           9
# gift          5
# tetra         5
# Name: container, dtype: int64
#
# none    3537
# JS       588
# RP       567
# WE       305
# WS       208
#         ...
# GP         1
# KWG        1
# BL         1
# HWC        1
# VA         1
# Name: critic, Length: 67, dtype: int64

# %%
# Use Sturgess' rule to suggest optimal number of bins based on sample size
int(1 + 3.322 * np.log(dfl.shape[0]))
# Out:
# 29

# %%
dfl.hist(bins=29, figsize=(15, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A008E37220>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A008E51640>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A008E72AC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A008E9FF10>]],
#       dtype=object)

# %% [markdown]
# ### Finally, analyse Vivino data

# %%
# Summary stats of continuous variables
dfv.describe()
# Out:
#          num_reviews         rating        acidity      intensity  \
# count  941275.000000  941275.000000  828493.000000  828493.000000
# mean       40.098653       4.700066       3.612646       4.165026
# std        22.774420       0.002767       0.421161       0.721823
# min        25.000000       4.600000       1.559409       2.283551
# 25%        39.000000       4.700000       3.366932       3.495921
# 50%        40.000000       4.700000       3.475289       4.413494
# 75%        40.000000       4.700000       3.965359       4.768188
# max      5476.000000       4.900000       4.823488       5.000000
#
#            sweetness         tannin
# count  828493.000000  828493.000000
# mean        1.732531       3.290282
# std         0.302884       0.484260
# min         1.000000       1.849303
# 25%         1.501577       3.077158
# 50%         1.647406       3.278753
# 75%         1.984824       3.522611
# max         3.692004       4.633800

# %%
# Value count of categorical variables
categorical = ['name', 'region', 'country', 'varietal', 'body']

for feature in categorical:
    print(dfv[feature].value_counts())
    print('')
# Out:
# Reverie Cabernet Sauvignon Special Reserve 2013       37571
# Bello Cabernet Sauvignon 2007                         37571
# Bernard Magrez Napa Valley Cabernet Sauvignon 2010    37571
# Buccella Mica Cabernet Sauvignon 2017                 37571
# Le Chiuse Brunello di Montalcino 1999                 37571
#                                                       ...
# Lynmar Estate Quail Hill Vineyard Pinot Noir 2015         1
# Verite La Joie 2012                                       1
# Vieux Château Certan Pomerol 2016                         1
# A. Rafanelli Merlot 2015                                  1
# Lapostolle Clos Apalta (Limited Release) 2005             1
# Name: name, Length: 2025, dtype: int64
#
# Napa Valley            113079
# Échezeaux Grand Cru     75162
# Priorat                 75161
# Oakville                59211
# Rutherford              37629
#                         ...
# Szekszárd                   1
# Piemonte                    1
# Paestum                     1
# Mount Harlan                1
# Vale dos Vinhedos           1
# Name: region, Length: 172, dtype: int64
#
# United States    429092
# France           113202
# Italy            112999
# Spain            112861
# Portugal          37649
# Chile             37595
# Hungary           37575
# Canada            37572
# South Africa      22586
# Argentina            63
# Australia            50
# Israel                4
# New Zealand           3
# Macedonia             2
# Austria               2
# Brazil                1
# Mexico                1
# Greece                1
# Georgia               1
# Romania               1
# Germany               1
# Croatia               1
# Name: country, dtype: int64
#
# Cabernet Sauvignon         219432
# Red Blend                  171866
# Côte de Nuits Red          112926
# Priorat Red                 75161
# Red                         37677
# Douro Red                   37624
# Brunello                    37618
# Barolo                      37599
# Rioja Red                   37585
# Cabernet Franc              34287
# Syrah                       22600
# Bordeaux Blend               3468
# Amarone                        86
# Ribera Del Duero Red           83
# Pomerol                        60
# Pauillac                       50
# Saint-Émilion                  45
# Pinot Noir                     33
# Malbec                         30
# Côte-Rotie                     29
# Margaux                        25
# Châteauneuf-du-Pape Red        25
# Shiraz                         23
# Alentejo Red                   21
# Cabernet - Shiraz              19
# Pessac-Léognan                 15
# Barbaresco                     14
# Bolgheri                       13
# Toro Red                       13
# Rhône Blend                    12
# Cabernet - Malbec              11
# Hermitage                      10
# Nebbiolo                       10
# Primitivo                       6
# Côte de Beaune Red              4
# Pinotage                        3
# Carménère                       3
# Saint-Estèphe                   2
# Zinfandel                       2
# Barbera                         2
# Syrah - Viognier                2
# Merlot                          2
# Saint-Julien                    2
# Grenache                        1
# Dornfelder                      1
# Tempranillo                     1
# Cabernet - Syrah                1
# Bonarda                         1
# Meritage                        1
# Name: varietal, dtype: int64
#
# Very full-bodied    339063
# Full-bodied         266978
# Medium-bodied       222458
# Light-bodied             5
# Name: body, dtype: int64

# %%
dfv.loc[dfv['name'] == 'Reverie Cabernet Sauvignon Special Reserve 2013']
# Out:
#                                                    name  \
# 2017    Reverie Cabernet Sauvignon Special Reserve 2013
# 2042    Reverie Cabernet Sauvignon Special Reserve 2013
# 2067    Reverie Cabernet Sauvignon Special Reserve 2013
# 2092    Reverie Cabernet Sauvignon Special Reserve 2013
# 2117    Reverie Cabernet Sauvignon Special Reserve 2013
# ...                                                 ...
# 941167  Reverie Cabernet Sauvignon Special Reserve 2013
# 941192  Reverie Cabernet Sauvignon Special Reserve 2013
# 941217  Reverie Cabernet Sauvignon Special Reserve 2013
# 941242  Reverie Cabernet Sauvignon Special Reserve 2013
# 941267  Reverie Cabernet Sauvignon Special Reserve 2013
#
#                            region        country  num_reviews  rating  \
# 2017    Diamond Mountain District  United States           40     4.7
# 2042    Diamond Mountain District  United States           40     4.7
# 2067    Diamond Mountain District  United States           40     4.7
# 2092    Diamond Mountain District  United States           40     4.7
# 2117    Diamond Mountain District  United States           40     4.7
# ...                           ...            ...          ...     ...
# 941167  Diamond Mountain District  United States           40     4.7
# 941192  Diamond Mountain District  United States           40     4.7
# 941217  Diamond Mountain District  United States           40     4.7
# 941242  Diamond Mountain District  United States           40     4.7
# 941267  Diamond Mountain District  United States           40     4.7
#
#          acidity fizziness  intensity  sweetness   tannin            varietal  \
# 2017    3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
# 2042    3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
# 2067    3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
# 2092    3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
# 2117    3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
# ...          ...       ...        ...        ...      ...                 ...
# 941167  3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
# 941192  3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
# 941217  3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
# 941242  3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
# 941267  3.366932      None   4.768188   1.482458  3.24634  Cabernet Sauvignon
#
#                     body
# 2017    Very full-bodied
# 2042    Very full-bodied
# 2067    Very full-bodied
# 2092    Very full-bodied
# 2117    Very full-bodied
# ...                  ...
# 941167  Very full-bodied
# 941192  Very full-bodied
# 941217  Very full-bodied
# 941242  Very full-bodied
# 941267  Very full-bodied
#
# [37571 rows x 12 columns]
