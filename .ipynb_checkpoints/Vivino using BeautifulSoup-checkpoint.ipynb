# %% [markdown]
# # Use BeatifulSoup to scrape red wine data from Vivino using LCBO data

# %% [markdown]
# This notebook goes through iterative steps to connect to the Vivino webpage and then scrape salient data associated with all the red wine items based on data scraped from LCBO. The most important information is the name, rating and number of reviews.

# %%
import re
import requests
import time
import random
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %%
dfl = pd.read_csv('lcbo_redwine.csv')

# %%
dfl['search'] = dfl['name'] + ' ' + dfl['region']

# %%
len(list(dfl['search']))
# Out:
# 6089

# %%
url = 'https://www.vivino.com/search/wines?q={kw}&start={page}'
prices_url = 'https://www.vivino.com/prices'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}

def get_wines(kw):
    with requests.session() as s:
        page = 1
        soup = BeautifulSoup(s.get(url.format(kw=kw, page=page), headers=headers).content, 'html.parser')
        params = [wc['data-vintage'] for wc in soup.select('.default-wine-card')]
        print(str(params[0]))
        
        title = soup.find('div', attrs={'class': 'default-wine-card vintage-price-id-'+str(params[0])})\
        .find('span', attrs={'class': 'bold'}).get_text().strip()
        
        region, country = soup.find('div', attrs={'class': 'default-wine-card vintage-price-id-'+str(params[0])}).\
        find('span', attrs={'class': 'text-block wine-card__region'}).get_text().strip().split('\n·\n')
        
        score = soup.find('div', attrs={'class': 'default-wine-card vintage-price-id-'+str(params[0])}).\
        find('div', attrs={'class': 'text-inline-block light average__number'}).get_text().strip()
        score = float(score.replace(',','.'))
        
        num_reviews = soup.find('div', attrs={'class': 'default-wine-card vintage-price-id-'+str(params[0])}).\
        find('div', attrs={'class': 'text-inline-block average__stars'}).get_text().strip()
        num_reviews = int(re.findall('\d*\ ',num_reviews)[0].strip())
        
        yield title, region, country, score, num_reviews
        
        time.sleep(random.randint(1,3))
            

#wines = ['Solaia 2009 Tuscany, Italy']
wines = list(missed['search'])[0:50]

total = len(wines)
i=1
with open('missed_redwine_1.csv', 'w', encoding='utf-8', newline='') as csvfile:
    bottle_writer = csv.writer(csvfile)
    bottle_writer.writerow(['title','region','country','score','num_reviews']) 
    for wine in wines:
        try:
            bottle = list(*get_wines(wine))
        except:
            bottle = ['missed','missed','missed',0,0]
        bottle_writer.writerow(bottle)
        print('Finished bottle ' + str(i) + ' of ' + str(total))
        i += 1
# Out:
# 110487056
# Finished bottle 1 of 50
# 4235548
# Finished bottle 2 of 50
# 1469826
# Finished bottle 3 of 50
# 1520027
# Finished bottle 4 of 50
# 1472069
# Finished bottle 5 of 50
# 2087473
# Finished bottle 6 of 50
# 1773078
# Finished bottle 7 of 50
# 1629830
# Finished bottle 8 of 50
# 1565338
# Finished bottle 9 of 50
# 4943495
# Finished bottle 10 of 50
# 1629830
# Finished bottle 11 of 50
# 1629830
# Finished bottle 12 of 50
# 158768842
# Finished bottle 13 of 50
# 1469826
# Finished bottle 14 of 50
# 1629830
# Finished bottle 15 of 50
# 2187424
# Finished bottle 16 of 50
# 4873858
# Finished bottle 17 of 50
# 1487425
# Finished bottle 18 of 50
# 67002882
# Finished bottle 19 of 50
# 4052882
# Finished bottle 20 of 50
# 3255632
# Finished bottle 21 of 50
# 1469826
# Finished bottle 22 of 50
# 1473613
# Finished bottle 23 of 50
# 1516734
# Finished bottle 24 of 50
# 1558662
# Finished bottle 25 of 50
# 160101819
# Finished bottle 26 of 50
# 9817832
# Finished bottle 27 of 50
# 140383230
# Finished bottle 28 of 50
# 140383230
# Finished bottle 29 of 50
# 2587741
# Finished bottle 30 of 50
# 24581102
# Finished bottle 31 of 50
# 9817832
# Finished bottle 32 of 50
# 60367301
# Finished bottle 33 of 50
# 1502944
# Finished bottle 34 of 50
# 1522493
# Finished bottle 35 of 50
# 4943495
# Finished bottle 36 of 50
# 1471333
# Finished bottle 37 of 50
# 3145294
# Finished bottle 38 of 50
# 4797765
# Finished bottle 39 of 50
# 3255632
# Finished bottle 40 of 50
# 140383230
# Finished bottle 41 of 50
# 4724594
# Finished bottle 42 of 50
# 1690477
# Finished bottle 43 of 50
# 1679918
# Finished bottle 44 of 50
# 3200615
# Finished bottle 45 of 50
# 2280748
# Finished bottle 46 of 50
# 14556273
# Finished bottle 47 of 50
# 2187424
# Finished bottle 48 of 50
# 2187424
# Finished bottle 49 of 50
# 2187424
# Finished bottle 50 of 50

# %%
dfv = pd.read_csv('vivino_lcbomatch_redwine.csv')

# %%
dfv['title'].isna().value_counts()
# Out:
# True     3760
# False    2329
# Name: title, dtype: int64

# %%
missed = dfl[dfv['title'].isna()]

# %%
missed
# Out:
#                                             name                   region  \
# 50                  Château Troplong Mondot 2010         Bordeaux, France
# 51                                         Macán             Rioja, Spain
# 52                                   Solaia 2005           Tuscany, Italy
# 53                                    Único 2006  Ribera del Duero, Spain
# 54                                   Pingus 2011  Ribera del Duero, Spain
# ...                                          ...                      ...
# 6055  Cuvee Mythique Halloween Edition Pays Doc*                   France
# 6056           Cupcake Black Forest Decadent Red          California, USA
# 6057        Citra Sangiovese Terre Di Chieti IGP           Abruzzo, Italy
# 6058   Vinetti de Fiorini Chianti Superiore DOCG           Tuscany, Italy
# 6059                   Negrar Corvina Verona IGT            Veneto, Italy
#
#       size-mL container    price critic  critic_score  \
# 50       3000    bottle  1595.00     RP          98.0
# 51       6000    bottle  1589.00   none           0.0
# 52       1500    bottle  1584.00     WS          97.0
# 53       1500    bottle  1580.00     RP          98.0
# 54        750    bottle  1575.00     RP          95.0
# ...       ...       ...      ...    ...           ...
# 6055      750    bottle     8.15   none           0.0
# 6056      750    bottle     8.15   none           0.0
# 6057      750    bottle     8.15   none           0.0
# 6058      750    bottle     8.15   none           0.0
# 6059      750    bottle     8.15   none           0.0
#
#                                                  search
# 50        Château Troplong Mondot 2010 Bordeaux, France
# 51                                   Macán Rioja, Spain
# 52                           Solaia 2005 Tuscany, Italy
# 53                   Único 2006 Ribera del Duero, Spain
# 54                  Pingus 2011 Ribera del Duero, Spain
# ...                                                 ...
# 6055  Cuvee Mythique Halloween Edition Pays Doc* France
# 6056  Cupcake Black Forest Decadent Red California, USA
# 6057  Citra Sangiovese Terre Di Chieti IGP Abruzzo, ...
# 6058  Vinetti de Fiorini Chianti Superiore DOCG Tusc...
# 6059            Negrar Corvina Verona IGT Veneto, Italy
#
# [3760 rows x 8 columns]

# %%
wines = list(missed['search'])[13]

# %%
wines
# Out:
# 'Solaia 2009 Tuscany, Italy'

# %%
dfm2 = pd.read_csv('missed_redwine_1.csv')
dfm2
# Out:
#                                                 title  \
# 0          Château Troplong Mondot Un Amour de Mondot
# 1   Benjamin de Rothschild - Vega Sicilia Macán Cl...
# 2                 Antinori Tenuta Tignanello 'Solaia'
# 3                                  Vega Sicilia Unico
# 4                    Dominio de Pingus Flor de Pingus
# 5      Álvaro Palacios L'Ermita Velles Vinyes Priorat
# 6      Domaine de La Romanée-Conti La Tâche Grand Cru
# 7                  A. de Luze Château Latour Bordeaux
# 8   Domaine de La Romanée-Conti Romanée-Saint-Viva...
# 9                    Château Canon Montségur Bordeaux
# 10                 A. de Luze Château Latour Bordeaux
# 11                 A. de Luze Château Latour Bordeaux
# 12                                             missed
# 13                Antinori Tenuta Tignanello 'Solaia'
# 14                 A. de Luze Château Latour Bordeaux
# 15  Les Grands Chais de France Château Londre Bord...
# 16                         Château du Tertre Bordeaux
# 17   Domaine de La Romanée-Conti Richebourg Grand Cru
# 18                  Château Le Clos du Merle Bordeaux
# 19                     M. Chapoutier Ermitage Le Méal
# 20                       Fontanafredda Barolo Riserva
# 21                Antinori Tenuta Tignanello 'Solaia'
# 22                                        Pintia Toro
# 23  Dal Forno Romano Amarone della Valpolicella Mo...
# 24                               Luce della Vite Luce
# 25                 Scotto Family Cellars USA Cabernet
# 26                                             missed
# 27            Château Larrivet Haut-Brion Le Bordeaux
# 28            Château Larrivet Haut-Brion Le Bordeaux
# 29                                             missed
# 30      Bryant Family Vineyard DB4 Cabernet Sauvignon
# 31                                             missed
# 32  Julia Hill Wines Julia Hill 2010 Shiraz - Coon...
# 33                         Tenuta San Guido Sassicaia
# 34        Biondi-Santi Brunello di Montalcino Riserva
# 35                   Château Canon Montségur Bordeaux
# 36                                Antinori Tignanello
# 37             Marchesi di Barolo Grignolino Piemonte
# 38   Château Haut-Bailly Rosé de Haut-Bailly Bordeaux
# 39                       Fontanafredda Barolo Riserva
# 40            Château Larrivet Haut-Brion Le Bordeaux
# 41  Kapcsandy State Lane Vineyard Cabernet Sauvign...
# 42                 Château Rauzan-Ségla Ségla Margaux
# 43     Taylors / Wakefield Jaraman Cabernet Sauvignon
# 44                       Clarendon Hills Moritz Syrah
# 45                     A.F. Gros Richebourg Grand Cru
# 46   Masi Mazzano Amarone Della Valpolicella Classico
# 47  Les Grands Chais de France Château Londre Bord...
# 48  Les Grands Chais de France Château Londre Bord...
# 49  Les Grands Chais de France Château Londre Bord...
#
#                                  region        country  score  num_reviews
# 0                         Saint-Émilion         France    4.3           29
# 1                                 Rioja          Spain    4.3         9621
# 2                               Toscana          Italy    4.6        24845
# 3                      Ribera del Duero          Spain    4.7        33882
# 4                      Ribera del Duero          Spain    4.5        23145
# 5                               Priorat          Spain    4.6         1730
# 6                    La Tâche Grand Cru         France    4.7         7652
# 7                              Bordeaux         France    4.4           18
# 8        Romanée-Saint-Vivant Grand Cru         France    4.7         4893
# 9                              Bordeaux         France    3.3           77
# 10                             Bordeaux         France    4.4           18
# 11                             Bordeaux         France    4.4           18
# 12                               missed         missed    0.0            0
# 13                              Toscana          Italy    4.6        24845
# 14                             Bordeaux         France    4.4           18
# 15                             Bordeaux         France    2.6           19
# 16                             Bordeaux         France    3.3          614
# 17                 Richebourg Grand Cru         France    4.7         4167
# 18                             Bordeaux         France    3.5           79
# 19                            Hermitage         France    4.4         1159
# 20                               Barolo          Italy    4.1         1951
# 21                              Toscana          Italy    4.6        24845
# 22                                 Toro          Spain    4.3        42470
# 23           Amarone della Valpolicella          Italy    4.7         5848
# 24                              Toscana          Italy    4.4        12362
# 25                           California  United States    3.4           83
# 26                               missed         missed    0.0            0
# 27                             Bordeaux         France    3.6          972
# 28                             Bordeaux         France    3.6          972
# 29                               missed         missed    0.0            0
# 30                          Napa Valley  United States    4.5           81
# 31                               missed         missed    0.0            0
# 32                           Coonawarra      Australia    3.7           21
# 33                   Bolgheri Sassicaia          Italy    4.6        79429
# 34               Brunello di Montalcino          Italy    4.6         2811
# 35                             Bordeaux         France    3.3           77
# 36                              Toscana          Italy    4.5       102434
# 37                             Piemonte          Italy    3.4          402
# 38                             Bordeaux         France    3.8          162
# 39                               Barolo          Italy    4.1         1951
# 40                             Bordeaux         France    3.6          972
# 41                          Napa Valley  United States    4.6          662
# 42                              Margaux         France    4.1         9562
# 43                      South Australia      Australia    3.8         2518
# 44                      South Australia      Australia    4.1          407
# 45                 Richebourg Grand Cru         France    4.4          785
# 46  Amarone della Valpolicella Classico          Italy    4.5         2314
# 47                             Bordeaux         France    2.6           19
# 48                             Bordeaux         France    2.6           19
# 49                             Bordeaux         France    2.6           19

# %%
tmp = ('missed','missed','missed','missed','missed')

# %%
list(tmp)
# Out:
# ['missed', 'missed', 'missed', 'missed', 'missed']

# %%
*tmp
# Out:
#   File "<ipython-input-25-ca40ad2e4bf3>", line 1
#     *tmp
#     ^
# SyntaxError: can't use starred expression here

# %%
*list(tmp)
# Out:
#   File "<ipython-input-26-5b1e469ee5e3>", line 1
#     *list(tmp)
#     ^
# SyntaxError: can't use starred expression here

# %%
print(*tmp)
# Out:
# missed missed missed missed missed

# %%
print(*list(tmp))
# Out:
# missed missed missed missed missed
